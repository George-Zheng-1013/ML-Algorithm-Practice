# %%
#留一法
from sklearn.model_selection import LeaveOneOut
data=[1,2,3,4]
loo=LeaveOneOut()
for train,test in loo.split(data):
  print(train,' ',test,'\n')
# Out:
# [1 2 3]   [0]
#
# [0 2 3]   [1]
#
# [0 1 3]   [2]
#
# [0 1 2]   [3]
